# %% [markdown]
# <a href="https://colab.research.google.com/github/pharringtonp19/business-analytics/blob/main/homeworks/HW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The following code will load in a data set corresponding to the 2024 WNBA season. If you need to know what the variables mean you can find the original dataset [here](https://www.basketball-reference.com/wnba/years/2024_per_game.html):

# %% [markdown]
# ### **Clone Business Analytics Repository**

# %%
# !git clone https://github.com/pharringtonp19/business-analytics.git
# Out:
# fatal: destination path 'business-analytics' already exists and is not an empty directory.

# %% [markdown]
# ### **Import Libraries**

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### **Read In the Dataset**

# %%
df = pd.read_csv('/content/business-analytics/datasets/sportsref_download.csv')

# %% [markdown]
# ### Question #0 (**Code**)
#
# Show the first 5 rows of the DataFrame

# %% [markdown]
# ### Question #1 (**Code**)
#
# Using the `.value_counts()` method, create a **meaningful** frequency table of FG%. By meaningful I mean the table should give you an informative sense of the frequency of the FG% values.

# %% [markdown]
# ### Question #2 (**Written**)
# Explain that the following code does:

# %%
plt.plot(df.G)
plt.show()

# %% [markdown]
# ### Question #3 (**Code**)
#
# Create a new data set that contains only observations in rows from 20-50 inclusive and the columns games (**G**) through field goal percentage (**FG%**)

# %% [markdown]
# ### Question #4 (**Code**)
#
# Create a Scatter plot of Assits (**AST**) and Points (**PTS**). I've included helper code for the `xlabel` and `title` that you can uncomment.

# %%
# plt.xlabel('Assists')
# plt.title('Points', loc='left')
# plt.show()

# %% [markdown]
# ### Question #5 (**Code**)
#
# Adjust the previous plot to color the observation associated with Caitlin Clark red (see the Python Grab bag in Class Notes #8 for help)

# %% [markdown]
# ### Question #6 (**Code**)
# Calculate the correlation coefficient between assists and points

# %% [markdown]
# ### Question #7 (**Code**)
#
# Create a scatter plot of assists per minute v.s.points per minute. Also calculate the correlation coefficient of these two variables. Does the relationship differ substantially from your previous work?

# %% [markdown]
# ### Question #8 (**Code**)
#
# Re-create your work for question #7, but drop players who average less than 5 minutes per game. What does the relationship look like now?

# %% [markdown]
# ### Question #9 (**Code**)
#
# What's the relationship (correlation coefficient) between turnovers (**TOV**) and assists per game?

# %% [markdown]
# ### Question #10 (**Code**)
# Create a new dataset that only consists of players who average more than 5 minutes per game and have played more than 10 games this year.

# %% [markdown]
# ### Question #11 (**Code**)
# How many players who average more than 5 minutes per game and played in more than 10 games this year have a higher shooting percentage from 3 (**3P%**) than from 2 (**2P%**)?

# %% [markdown]
# ### Question #12 (**Code**)
# Restrict the dataset to players who shoot 40% or higher from three. Create a relative frequency table of positions (**Pos**) for this subset.

# %% [markdown]
# ### Question #13 (**Code**)

# %% [markdown]
# ### Question #14 (**Code**)
#
# Create a the following plot: Let the x-axis be the minutes played per-game. And let the y-axis be the average 2-point shooting percentage (**2P%**) for players who have played at least the number of minutes as specified by the x-axis.

# %% [markdown]
# ### Question #15 (**Code**)
# List the in descending order the top five pure guards (Pos==G) with the most rebounds per game.

# %% [markdown]
# ### Question #16 (**Code**)
#
# Create the following correlation matrix. I have written some helper code to get you started.
#
# Your aim is to create a lists of lists called `results`. For each inner list, you want to compute the correlation coefficients between a specific column and all of the columns specified in the correlation matrix. Your inner lists should differ by the reference variable. For instance, the reference variable in your first inner list should be **3P%**, and each value in your first inner lists should be the correlation coefficient between **3P%** and each of the variables in the correlation matrix. In your second list, the reference variable should be **2P%**, and so on.
#
# ![Screenshot 2024-09-20 at 6.06.52 PM.png](data:image/png;base64,...)

# %%
# plt.imshow(results)
# plt.colorbar(label='Correlation Coefficient')
# plt.xticks(ticks=np.arange(len(cols)), labels=cols, rotation=45, ha='right')
# plt.yticks(ticks=np.arange(len(cols)), labels=cols)
# plt.title('Correlation Matrix')
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ### Question #16 (**Code**)
# Make a statistical argument for why Caitlyn Clark should or should not be the MVP of the WNBA
