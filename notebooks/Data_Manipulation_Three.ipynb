# %% [markdown]
# <a href="https://colab.research.google.com/github/pharringtonp19/business-analytics/blob/main/notebooks/Data_Manipulation_Three.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Clone Business Analytics Repository**

# %%
# !git clone https://github.com/pharringtonp19/business-analytics.git
# Out:
# Cloning into 'business-analytics'...
# remote: Enumerating objects: 416, done.
# remote: Counting objects: 100% (214/214), done.
# remote: Compressing objects: 100% (192/192), done.
# remote: Total 416 (delta 125), reused 27 (delta 18), pack-reused 202 (from 1)
# Receiving objects: 100% (416/416), 7.45 MiB | 10.21 MiB/s, done.
# Resolving deltas: 100% (215/215), done.

# %% [markdown]
# ### **Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### **A Function Without a Name**

# %%
lambda x: x**2
# Out:
# <function __main__.<lambda>(x)>

# %%
(lambda x: x**2)(4)
# Out:
# 16

# %% [markdown]
# ### Map

# %% [markdown]
# ### **Read In Data**

# %%
file_path = '/content/business-analytics/datasets/atlanta_evictions.xls'
df = pd.read_excel(file_path, skiprows=3)
df.columns = df.columns.str.replace('Filings in ', '')
df.head()
# Out:
#                          Street           City    Zip  countyFIPS  \
# 0                8050 TAYLOR RD      RIVERDALE  30274          63
# 1            3100 SWEETWATER RD  LAWRENCEVILLE  30044         135
# 2           1955 BELLS FERRY RD       MARIETTA  30066          67
# 3  1100 INDIAN TRAIL LILBURN RD       NORCROSS  30093         135
# 4                  1507 PINE DR   COLLEGE PARK  30349          63
#
#        tractID  Jan 2020  Feb 2020  Mar 2020  Apr 2020  May 2020  ...  \
# 0  13063040516        25        31        21        26        22  ...
# 1  13135050541        32        36        41         0         0  ...
# 2  13067030601        15        43        19         0         0  ...
# 3  13135050424        28        25        14         0         0  ...
# 4  13063040204        12        21        16        17         7  ...
#
#    Apr 2023  May 2023  Jun 2023  Jul 2023  Aug 2023  Sep 2023  Oct 2023  \
# ...

# %% [markdown]
# ### **Histogram of Eviction Filings**

# %%
df.loc[:, "Jan 2020": ].head()
# Out:
#    Jan 2020  Feb 2020  Mar 2020  Apr 2020  May 2020  Jun 2020  Jul 2020  \
# 0        25        31        21        26        22        26        25
# 1        32        36        41         0         0         0         0
# 2        15        43        19         0         0         0         0
# 3        28        25        14         0         0         0         0
# 4        12        21        16        17         7        12         9
#
#    Aug 2020  Sep 2020  Oct 2020  ...  Apr 2023  May 2023  Jun 2023  Jul 2023  \
# 0        24        20        26  ...        33        28        33        33
# 1         0         0         9  ...        32        21        25        28
# 2         0        11        33  ...         8        27        41        18
# 3        38         0        22  ...        25        21        26        14
# 4        11         9        16  ...        16        29        16        26
#
#    Aug 2023  Sep 2023  Oct 2023  Nov 2023  Dec 2023  Jan 2024
# ...

# %%
values_array = df.loc[:, "Jan 2020": ].values
flattened_array = values_array.flatten()
plt.hist(flattened_array, bins=20, edgecolor='black')
plt.show()

# %% [markdown]
# ### **Check Your Understanding**
# In a single figure, plot the time series of evictions for each building.

# %%
for i in df.index:
  row = df.loc[i]
  plt.plot(row[5:])
plt.title('Eviction Filings', loc='left')
plt.xticks(ticks=range(0, len(df.columns[5:]), 12), rotation=0)
plt.show()

# %%
for i in df.index:
  row = df.loc[i]
  plt.plot(row[5:])
plt.title('Eviction Filings', loc='left')
plt.xticks(ticks=range(0, len(df.columns[5:]), 12), rotation=0)
plt.show()

# %% [markdown]
# ### **Count the Number of Buildings in Each Zip Code**

# %%
num_buildings = df.groupby('Zip').size()
plt.hist(num_buildings, edgecolor='black')
plt.xlabel('Number of Buildings Per Zip Code')
plt.title('Count', loc='left')
plt.show()
