# %% [markdown]
# <a href="https://colab.research.google.com/github/pharringtonp19/business-analytics/blob/main/notebooks/Data_Manipulation_Three_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Clone Business Analytics Repository**

# %%
# !git clone https://github.com/pharringtonp19/business-analytics.git
# Out:
# Cloning into 'business-analytics'...
# remote: Enumerating objects: 416, done.
# remote: Counting objects: 100% (214/214), done.
# remote: Compressing objects: 100% (192/192), done.
# remote: Total 416 (delta 125), reused 27 (delta 18), pack-reused 202 (from 1)
# Receiving objects: 100% (416/416), 7.45 MiB | 10.21 MiB/s, done.
# Resolving deltas: 100% (215/215), done.

# %% [markdown]
# ### **Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### **Read In Data**

# %%
file_path = '/content/business-analytics/datasets/atlanta_evictions.xls'
df = pd.read_excel(file_path, skiprows=3)
df.columns = df.columns.str.replace('Filings in ', '')
# Out:
#                          Street           City    Zip  countyFIPS  \
# 0                8050 TAYLOR RD      RIVERDALE  30274          63
# 1            3100 SWEETWATER RD  LAWRENCEVILLE  30044         135
# 2           1955 BELLS FERRY RD       MARIETTA  30066          67
# 3  1100 INDIAN TRAIL LILBURN RD       NORCROSS  30093         135
# 4                  1507 PINE DR   COLLEGE PARK  30349          63
#
#        tractID  Jan 2020  Feb 2020  Mar 2020  Apr 2020  May 2020  ...  \
# 0  13063040516        25        31        21        26        22  ...
# 1  13135050541        32        36        41         0         0  ...
# 2  13067030601        15        43        19         0         0  ...
# 3  13135050424        28        25        14         0         0  ...
# 4  13063040204        12        21        16        17         7  ...
#
#    Apr 2023  May 2023  Jun 2023  Jul 2023  Aug 2023  Sep 2023  Oct 2023  \
# ...
