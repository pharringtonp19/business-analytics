# %% [markdown]
# <a href="https://colab.research.google.com/github/pharringtonp19/business-analytics/blob/main/notebooks/Intro_to_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Import Library**

# %%
import pandas as pd

# %% [markdown]
# ### **Define a Dictionary**

# %%
my_dict = {'vehicles': ['Toyota Camry', 'Ford Explorer', 'Tesla Model 3', 'Ford F-150', 'Honda Civic', 'Porsche 911', 'Toyota Prius', 'Toyota Tundra'], 'countries': ['USA', 'Canada', 'Mexico', 'Argentina', 'Italy', 'France', 'England', 'Germany'], 'sports': ['Basketball', 'Football', 'Soccer', 'Baseball', 'Hockley', 'Ping Pong', 'Sailing', 'Running']}

# %% [markdown]
# ### **Create the Pandas DataFrame**

# %%
df = pd.DataFrame(my_dict)

# %% [markdown]
# ### **Visualize the DataFrame**

# %%
df.head()
# Out:
#         vehicles  countries      sports
# 0   Toyota Camry        USA  Basketball
# 1  Ford Explorer     Canada    Football
# 2  Tesla Model 3     Mexico      Soccer
# 3     Ford F-150  Argentina    Baseball
# 4    Honda Civic      Italy     Hockley

# %%
df.tail()
# Out:
#         vehicles  countries     sports
# 3     Ford F-150  Argentina   Baseball
# 4    Honda Civic      Italy    Hockley
# 5    Porsche 911     France  Ping Pong
# 6   Toyota Prius    England    Sailing
# 7  Toyota Tundra    Germany    Running

# %% [markdown]
# ### **Index**

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %% [markdown]
# ### **Row**

# %%
df.loc[0]
# Out:
# vehicles     Toyota Camry
# countries             USA
# sports         Basketball
# Name: 0, dtype: object

# %%
df.loc[1:3]
# Out:
#         vehicles  countries    sports
# 1  Ford Explorer     Canada  Football
# 2  Tesla Model 3     Mexico    Soccer
# 3     Ford F-150  Argentina  Baseball

# %% [markdown]
# ### **Column**

# %%
df['countries']
# Out:
# 0          USA
# 1       Canada
# 2       Mexico
# 3    Argentina
# 4        Italy
# 5       France
# 6      England
# 7      Germany
# Name: countries, dtype: object

# %%
df[['countries', 'sports']]
# Out:
#    countries      sports
# 0        USA  Basketball
# 1     Canada    Football
# 2     Mexico      Soccer
# 3  Argentina    Baseball
# 4      Italy     Hockley
# 5     France   Ping Pong
# 6    England     Sailing
# 7    Germany     Running
