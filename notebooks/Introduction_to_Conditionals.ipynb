# %% [markdown]
# <a href="https://colab.research.google.com/github/pharringtonp19/business-analytics/blob/main/notebooks/Introduction_to_Conditionals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Task # 1**
# Write the following function in python

# %% [markdown]
# ![Screenshot 2024-09-11 at 9.33.20 AM.png](data:image/png;base64,...)

# %% [markdown]
# #### **Function**

# %%
def lottery(ticket, drawn_number):
  if ticket == drawn_number:
    print("You won the lottery!")
  else:
    print("Try again!")

# %%
my_ticket = 4
wed_draw = 4

lottery(my_ticket, wed_draw)
# Out:
# You won the lottery!

# %%
my_ticket = 8
wed_draw = 3

lottery(my_ticket, wed_draw)
# Out:
# Try again!

# %% [markdown]
# ### **Task # 2**
#
# Write the following function in Python

# %% [markdown]
# ![Screenshot 2024-09-11 at 9.36.38 AM.png](data:image/png;base64,...)

# %% [markdown]
# #### **Function**

# %%
def game(home_score, away_score):

  if home_score > away_score:
    print("The Home team won!")

  elif home_score < away_score:
    print("The Away team won!")

  else:
    print("Tie")

# %%
h_score = 4
a_score = 3

game(h_score, a_score)
# Out:
# The Home team won!

# %%
h_score = 2
a_score = 2
game(h_score, a_score)
# Out:
# Tie

# %%
h_score = 1
a_score = 2
game(h_score, a_score)
# Out:
# The Away team won!
