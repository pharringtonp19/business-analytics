# %% [markdown]
# <a href="https://colab.research.google.com/github/pharringtonp19/business-analytics/blob/main/notebooks/regression/interpretation_categorical_variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/pharringtonp19/business-analytics.git
# Out:
# Cloning into 'business-analytics'...
# remote: Enumerating objects: 1289, done.
# remote: Counting objects: 100% (344/344), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 1289 (delta 316), reused 254 (delta 254), pack-reused 945 (from 1)
# Receiving objects: 100% (1289/1289), 21.86 MiB | 12.57 MiB/s, done.
# Resolving deltas: 100% (772/772), done.

# %% [markdown]
# ### **Import Packages**

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import statsmodels.formula.api as smf
from statsmodels.iolib.summary2 import summary_col
import plotly.graph_objects as go
import plotly.express as px
import numpy as np
import jax.numpy as jnp
import jax
import seaborn as sb
from functools import partial

# %% [markdown]
# ### **Read In Data Set**

# %%
df = pd.read_csv('/content/business-analytics/datasets/sodaSales.csv')
df.head()
# Out:
#    store  population  income  education  cost  competition  price  units_sold  \
# 0      1        2265   57.87         37  0.80            1   2.25        1018
# 1      2        2999   30.03          7  0.39            1   1.00         600
# 2      3        2579   60.30         34  0.64            1   1.75        2330
# 3      4        3766   48.11         44  0.95            1   3.00        2225
# 4      5        1560   40.42         22  0.69            0   1.75         593
#
#   promotion
# 0         B
# 1      NONE
# 2         B
# 3         B
# 4      NONE

# %% [markdown]
# ### **Value Counts of Control Variables**

# %%
df['promotion'].value_counts()
# Out:
# promotion
# B       256
# NONE    176
# A        64
# Name: count, dtype: int64

# %% [markdown]
# ### **Estimate Model**

# %%
linear_model = smf.ols('units_sold ~ promotion', data=df)
results = linear_model.fit()
results.params
# Out:
# Intercept            1171.937500
# promotion[T.B]         87.511719
# promotion[T.NONE]    -196.801136
# dtype: float64
